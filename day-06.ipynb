# %% [markdown]
# # Why do we need Data Structure?

# %%
# to minimize the storage issue
# to not have a lot of declared variables instead we can have a single storage where data can be stored and can easily be accessed

# %%
#Types of Data structures
# 1. List
# 2. Tuple
# 3. Set
# 4. Dictionary

# %%
l = [1,2,3,4,5]
print(l)
# Out:
# [1, 2, 3, 4, 5]

# %%
d = {1:'a',2:'b',3:'c'}
print(d)
print(d.items())
print(d.keys())
print(d.values())
# Out:
# {1: 'a', 2: 'b', 3: 'c'}
# dict_items([(1, 'a'), (2, 'b'), (3, 'c')])
# dict_keys([1, 2, 3])
# dict_values(['a', 'b', 'c'])
