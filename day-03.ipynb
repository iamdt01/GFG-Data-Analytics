# %% [markdown]
# # Problems

# %%
# 1. Taking Input
# You need to perform three separate tasks based on the given input:
# 
# String Input and Print: Read a string s (which may contain spaces) and print it as it is.
# Integer Input and Print: Read an integer n and print it without any change.
# Float Input and floor Print: Read a floating-point number as input, take its floor value, and print as an integer.
# Examples:
# 
# Input: s = "Hello", n = 20, f = 5.5
# Output: 
# Hello
# 20
# 5
# Explanation: 
# The string Hello is printed as it is.
# The integer 20 is printed without any change.
# For floating-point number 5.5, its floor value 5 is printed.
string_input = input("Enter a string: ")
print(string_input)
integer_input = int(input("Enter an integer: "))
print(integer_input)
float_input = float(input("Enter a floating-point number: "))
print(int(float_input))
# Out:
# Geeks For Geeks
# 1600
# 10

# %%
# 2. Start Coding
# The "Hello World" program is a common starting point for learning programming.
# Complete the code to print: "Hello World"
# 
# Example: 
# Output: Hello World
# Explanation: Prints the first message traditionally used to begin learning programming.
print("Hello World")
# Out:
# Hello World

# %%
# 3. Type Casting and Doubling it
# Given an input num as a string. You need to typecast into an integer and double it. 
# 
# Examples:
# 
# Input: num = "5"
# Output: 10
# Explanation: Typecast "5" to int and then double it 5 * 2 = 10
# Input: num = "12"
# Output: 24
# Explanation: Typecast "12" to int and then double it 12 * 2 = 24
# Constraints:
# 0 <= num <= 105
s = input("Enter a number : ")
s = int(s)
print(s*2)
# Out:
# 10

# %%
# 4. Arithmetic Operators
# Given two integer variables x and y, perform the following operations:
# 
# p: Addition of x and y
# q: Subtraction of y from x
# r: Multiplication of x and y
# s: Floating-point division of x by y
# t: Integer division of x by y
# u: Modulo (remainder when x is divided by y)
# Examples:
# 
# Input: x = 1, y = 2
# Output: 3 -1 2 0.500 0 1
# Explanation: The given operations are performed:
# Addition of x and y = 3
# Subtraction of y from x = -1
# Multiplication of x and y = 2
# Floating-point division of x by y = 0.500
# Integer division of x by y = 0
# Modulo of x and y = 1
# Hence, the output is 3 -1 2 0.500 0 1.
# Input: x = 3 ,y = 4 
# Output: 7 -1 12 0.750 0 3
# Explanation: The given operations are performed.
# Constraints:
# 
# -100 ≤ x ≤ 100
# -100 ≤ y ≤ 100
x = int(input("Enter the first number : "))
y = int(input("Enter the second number : "))
p = x+y
q = x-y
r = x*y
s = x/y
t = x//y
u = x%y
print('Addition :',p)
print('Subtraction :',q)
print('Multiplication :',r)
print('Floating-point division: ',s)
print('Integer division :',t)
print('Modulo :',u)
# Out:
# Addition : 3
# Subtraction : -1
# Multiplication : 2
# Floating-point division:  0.5
# Integer division : 0
# Modulo : 1

# %%
# 5. Logical Operators
# Given two values a and b, perform the logical operations a and b, a or b, and not a, and print the result of each operation on a new line.
# 
# The logical operators in Python behave as follows:
# 
# and: Returns the second operand if both operands are truthy; otherwise, returns the first falsy operand.
# or: Returns the first truthy operand. If both operands are falsy, it returns the second operand.
# not: Returns the boolean opposite of the operand.
# Note: In Python, 0 and an empty string ("") are treated as False (falsy), while all other values are treated as True (truthy).
# 
# Examples:
# 
# Input: a = 1, b = 0
# Output:
# 0
# 1
# False
# Explanation: a and b returns 0, a or b returns 1, and not a returns False.
# Input: a = 5, b = 6
# Output:
# 6
# 5
# False
# Explanation: a and b returns 6, a or b returns 5, and not a returns False
a , b = 1 , 0
print(a and b)
print(a or b)
print(not a)
a , b = 5 , 6
print(a and b)
print(a or b)
print(not a)
# Out:
# 0
# 1
# False
# 6
# 5
# False
